# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
dialogues = pd.read_csv("../data/dialouges_w_map.csv")
characters = pd.read_csv("../data/characters_w_map.csv")

# %%
# Initialize a dictionary to store accumulative sentiment and counts
speaker_sentiments = {}

# Create new columns in the dialogues dataframe
dialogues['accumulative_sentiment'] = 0.0
dialogues['average_sentiment'] = 0.0

# Iterate through each row in the dialogues dataframe with a progress bar
for index, row in tqdm(dialogues.iterrows(), total=len(dialogues), desc="Processing dialogues"):
    speaker = row['mapped']
    sentiment_score = row['sentiment_score']
    sentiment_label = row['sentiment_label']
    
    # Convert sentiment_label to a score: 1 for POSITIVE, -1 for NEGATIVE
    sentiment_sign = 1 if sentiment_label == 'POSITIVE' else -1
    
    # Update the sentiment score based on the label
    adjusted_sentiment_score = sentiment_sign * sentiment_score
    
    # Initialize speaker if not present in the dictionary
    if speaker not in speaker_sentiments:
        speaker_sentiments[speaker] = {'accumulative_sentiment': 0, 'sentiment_count': 0, 'sentiment_sign_sum': 0}
    
    # Update accumulative sentiment and sentiment count
    speaker_sentiments[speaker]['accumulative_sentiment'] += adjusted_sentiment_score
    speaker_sentiments[speaker]['sentiment_count'] += 1
    speaker_sentiments[speaker]['sentiment_sign_sum'] += sentiment_sign
    
    # Calculate average sentiment so far
    average_sentiment_so_far = speaker_sentiments[speaker]['sentiment_sign_sum'] / speaker_sentiments[speaker]['sentiment_count']
    
    # Update the dialogues dataframe with the calculated values
    dialogues.at[index, 'accumulative_sentiment'] = speaker_sentiments[speaker]['accumulative_sentiment']
    dialogues.at[index, 'average_sentiment'] = average_sentiment_so_far

# Save the updated dialogues dataframe
dialogues.to_csv("../data/dialouges_over_time.csv", index=False)

print("Updated dialogues dataframe has been saved.")
# Out:
# Processing dialogues: 100%|██████████| 20786/20786 [00:02<00:00, 7787.22it/s]
# Updated dialogues dataframe has been saved.

# %%
# Count the number of lines for each character
line_counts = dialogues['mapped'].value_counts()

# Get the top 20 characters with the most lines
top_20_characters = line_counts.head(20).reset_index()

# Rename columns for clarity
top_20_characters.columns = ['character', 'line_count']

# %%
top_20_characters
# Out:
#              character  line_count
# 0     tyrion lannister        1752
# 1             jon snow        1134
# 2   daenerys targaryen         967
# 3     cersei lannister         940
# 4      jaime lannister         931
# 5          sansa stark         800
# 6           arya stark         776
# 7        samwell tarly         553
# 8                davos         505
# 9        theon greyjoy         478
# 10               bronn         405
# 11               varys         388
# 12     tywin lannister         386
# 13       jorah mormont         381
# 14             brienne         378
# 15          bran stark         374
# 16          robb stark         329
# 17       catelyn stark         302
# 18            margaery         280
# 19              ramsay         270

# %%
# Select the last row for each unique speaker
end_sentiment_df = dialogues.groupby('mapped').tail(1)

# Create a new DataFrame with only the unique characters and their final scores
end_sentiment = end_sentiment_df[['mapped', 'accumulative_sentiment', 'average_sentiment']].reset_index(drop=True)

# Rename columns for clarity (optional)
end_sentiment.rename(columns={
    'mapped': 'speaker',
    'accumulative_sentiment': 'final_accumulative_sentiment',
    'average_sentiment': 'final_average_sentiment'
}, inplace=True)

# %%
df =end_sentiment.loc[end_sentiment['speaker'].isin(top_20_characters['character'])].sort_values(by='final_average_sentiment', ascending=False)
#df = end_sentiment.sort_values(by='final_average_sentiment', ascending=False)

df_dead = []


for index, row in df.iterrows():
    name_map = row['speaker']

    # check if the character is dead
    if pd.isna(characters.loc[characters['mapped']==name_map].Died.values[0]):
        df_dead.append(False)
    else:
        df_dead.append(True)
    
df['dead'] = df_dead

# %%
df
# Out:
#                 speaker  final_accumulative_sentiment  \
# 197            margaery                    232.034402
# 216              ramsay                    104.451694
# 246       jorah mormont                    106.587335
# 269               davos                     41.694621
# 253               varys                    -18.565441
# 270       samwell tarly                    -52.442450
# 272               bronn                    -88.092152
# 273    tyrion lannister                   -239.559026
# 267            jon snow                   -204.246940
# 254     jaime lannister                   -234.029204
# 256    cersei lannister                   -196.143225
# 127     tywin lannister                    -87.131138
# 268          bran stark                   -127.705704
# 243       theon greyjoy                   -151.740256
# 104          robb stark                   -101.052526
# 265         sansa stark                   -228.287708
# 271             brienne                   -122.387626
# 258  daenerys targaryen                   -353.050996
# 103       catelyn stark                   -143.562964
# 266          arya stark                   -515.027138
#
#      final_average_sentiment   dead
# 197                 0.192857   True
# 216                 0.096296   True
# 246                 0.018373   True
# 269                -0.005941  False
# 253                -0.051546   True
# 270                -0.063291  False
# 272                -0.071605  False
# 273                -0.078767  False
# 267                -0.097002   True
# 254                -0.106337   True
# 256                -0.108511   True
# 127                -0.113990   True
# 268                -0.117647  False
# 243                -0.125523   True
# 104                -0.130699   True
# 265                -0.137500  False
# 271                -0.158730  False
# 258                -0.160290   True
# 103                -0.192053   True
# 266                -0.244845  False

# %%
df.loc[(df['final_average_sentiment']!=1.0) & (df['final_average_sentiment']!=-1.0)].iloc[:40]
# Out:
#                 speaker  final_accumulative_sentiment  \
# 197            margaery                    232.034402
# 216              ramsay                    104.451694
# 246       jorah mormont                    106.587335
# 269               davos                     41.694621
# 253               varys                    -18.565441
# 270       samwell tarly                    -52.442450
# 272               bronn                    -88.092152
# 273    tyrion lannister                   -239.559026
# 267            jon snow                   -204.246940
# 254     jaime lannister                   -234.029204
# 256    cersei lannister                   -196.143225
# 127     tywin lannister                    -87.131138
# 268          bran stark                   -127.705704
# 243       theon greyjoy                   -151.740256
# 104          robb stark                   -101.052526
# 265         sansa stark                   -228.287708
# 271             brienne                   -122.387626
# 258  daenerys targaryen                   -353.050996
# 103       catelyn stark                   -143.562964
# 266          arya stark                   -515.027138
#
#      final_average_sentiment   dead
# 197                 0.192857   True
# 216                 0.096296   True
# 246                 0.018373   True
# 269                -0.005941  False
# 253                -0.051546   True
# 270                -0.063291  False
# 272                -0.071605  False
# 273                -0.078767  False
# 267                -0.097002   True
# 254                -0.106337   True
# 256                -0.108511   True
# 127                -0.113990   True
# 268                -0.117647  False
# 243                -0.125523   True
# 104                -0.130699   True
# 265                -0.137500  False
# 271                -0.158730  False
# 258                -0.160290   True
# 103                -0.192053   True
# 266                -0.244845  False

# %%
pd.isna(characters.loc[characters['mapped']=='samwell tarly'].Died.values[0])
# Out:
# True

# %%
# function that print all dialouge and sentiment for a given speaker
def print_dialouge_and_sentiment(speaker, df=dialogues, column = 'Speaker'):
    df = df.loc[df[column]== speaker]
    for index, row in df.iterrows():
        print(row['Text'], row['sentiment_label'])

# %%
print_dialouge_and_sentiment('tycho', df=dialogues, column = 'mapped')
# Out:
#  Welcome to the Iron Bank. Please, sit. POSITIVE
#  What can we do for you, Lord Stannis? NEGATIVE
#  The Iron Throne is currently occupied by Tommen of the House Baratheon, King of the Andals and the First Men, Lord of the Seven Kingdoms and Protector of the Realm. POSITIVE
#  Yes, we have heard this story. POSITIVE
#  The king's grandfather tells a different story. A story about a jealous uncle whose attempts to usurp the throne from the rightful king cost the Seven Kingdoms dearly in blood and gold. POSITIVE
#  And you feel your blood gives you a claim on our gold? POSITIVE
#  Across the Narrow Sea, your books are filled with words like "usurper" and "madman" and "blood right." Here, our books are filled with numbers. We prefer the stories they tell. More plain. Less open to interpretation. How many fighting men remain loyal to you? NEGATIVE
#  And how many ships do you have? The ones still afloat, Ser Davos, not at the bottom of Blackwater Bay. NEGATIVE
#  And how much wheat and barley and beef and pork do you produce on Dragonstone to feed your 4,000 men on your 32 ships? NEGATIVE
#  You can see why these numbers seem unlikely to add up to a happy ending from our perspective. I'm afraid we must respectfully decline your request. But we thank you for paying us the honor of your visit. POSITIVE
#  I'm not a lord, Ser Davos Seaworth. You would not be either here. In Braavos, thieves are not rewarded with titles. NEGATIVE
#  The war is over. NEGATIVE
#  Ser Davos... POSITIVE
#   Tywin Lannister. POSITIVE
#   67. POSITIVE
#  That is a problem for another time. NEGATIVE
#   No, thank you. POSITIVE
#   My condolences, Your Grace, on the death of your son.  From all reports he was a fine young man. POSITIVE
#   Condolences and congratulations.  You've become the first ruling queen in the Seven Kingdoms.  That's quite an accomplishment.  The Iron Bank appreciates how you cast off the yoke of superstition freeing the crown from elements that sought to subvert the rule of law. POSITIVE
#   Indeed.  But sometimes tragedies are necessary to restore order and rational leadership. POSITIVE
#   Your father never minced words either.  But, yes, your debts are considerable.  And you are now engaged in a conflict on several fronts.  We both know how expensive war can be. NEGATIVE
#   Your wealthiest ally is the Tyrells who are now your enemies.  You're surrounded on all sides by rivals for the throne. POSITIVE
#   We don't make bets.  We invest in endeavors we deem likely to be successful. POSITIVE
#   Euron Greyjoy's armada owns the Narrow Sea. NEGATIVE
#   For now.  Daenerys Targaryen has three full grown dragons.  How well do wooden ships fare against fire breathing dragons? NEGATIVE
#   The slave trade has entered a down turn, it's true. POSITIVE
#   Your father's daughter indeed. POSITIVE
#   I must say, I don't think the Iron Bank has ever had a debt of this magnitude repaid in a single installment.  I always considered your father a very effective and efficient man, but you appear to be redefining those terms entirely. POSITIVE
#   I am neither kind, nor a lord, Your Grace.  I am merely an instrument of the institution I represent, its wellbeing is a matter of arithmetic, not sentiment.  And the current arithmetic is outstanding.  The gold -- POSITIVE
#   Some at the Iron Bank will be disappointed.  They've grown rather fond of your interest payments. NEGATIVE
#   Yes.  Perhaps we could be of assistance in some current venture. NEGATIVE
#   I see a great deal of potential in that venture.  I imagine that it would require outside investment? POSITIVE
#   I know them well.  They've helped us recover significant sums from parties who had fallen into deep arrears. POSITIVE
#   Rest assured, Your Grace, you can count on the Iron Bank's support, as soon as the gold arrives. POSITIVE

# %%
dialogues
# Out:
#                                                     Text       Speaker  \
# 0       What d’you expect? They’re savages. One lot s...  WAYMAR ROYCE
# 1       I’ve never seen wildlings do a thing like thi...          WILL
# 2                                 How close did you get?  WAYMAR ROYCE
# 3                                Close as any man would.          WILL
# 4                       We should head back to the wall.         GARED
# ...                                                  ...           ...
# 20781   Uh the Archmaester is less than enthusiastic ...           SAM
# 20782      Well, I imagine he isn't using them properly.         BRONN
# 20783   I think we can all agree that ships take prec...       BRIENNE
# 20784      I think that's a very presumptuous statement.         BRONN
# 20785   I once brought a jackass and a honeycomb into...        TYRION
#
#                    Episode     Season             Show  sentiment_score  \
# 0      e1-Winter is Coming  season-01  Game-of-Thrones         2.843596
# 1      e1-Winter is Coming  season-01  Game-of-Thrones         2.763056
# 2      e1-Winter is Coming  season-01  Game-of-Thrones         0.582696
# 3      e1-Winter is Coming  season-01  Game-of-Thrones         2.810488
# 4      e1-Winter is Coming  season-01  Game-of-Thrones         3.263553
# ...                    ...        ...              ...              ...
# 20781                   e6  season-08  Game-of-Thrones         4.652675
# 20782                   e6  season-08  Game-of-Thrones         4.785044
# 20783                   e6  season-08  Game-of-Thrones         0.476380
# 20784                   e6  season-08  Game-of-Thrones         3.653502
# 20785                   e6  season-08  Game-of-Thrones         2.839989
#
#       sentiment_label            mapped bracket  accumulative_sentiment  \
# 0            NEGATIVE      waymar royce     NaN               -2.843596
# 1            POSITIVE              will     NaN                2.763056
# 2            NEGATIVE      waymar royce     NaN               -3.426292
# 3            POSITIVE              will     NaN                5.573544
# 4            NEGATIVE             gared     NaN               -3.263553
# ...               ...               ...     ...                     ...
# 20781        NEGATIVE               sam     NaN               13.813297
# 20782        NEGATIVE             bronn     NaN              -91.745654
# 20783        POSITIVE           brienne     NaN             -122.387626
# 20784        POSITIVE             bronn     NaN              -88.092152
# 20785        NEGATIVE  tyrion lannister     NaN             -239.559026
#
#        average_sentiment
# 0              -1.000000
# 1               1.000000
# 2              -1.000000
# 3               1.000000
# 4              -1.000000
# ...                  ...
# 20781          -0.012469
# 20782          -0.074257
# 20783          -0.158730
# 20784          -0.071605
# 20785          -0.078767
#
# [20786 rows x 11 columns]

# %%
dialouges = pd.read_csv("../data/dialouges_over_time.csv")

# %%
dialouges.loc[dialouges['mapped']=='ygritte'].iloc[9].Text
# Out:
# "  Hundreds and thousands. More than you've ever seen, crow."

# %%
characters
# Out:
#                           Name  \
# 0                        Aemon
# 1                        Anguy
# 2                   Lysa Arryn
# 3                  Robin Arryn
# 4                       Arthur
# ..                         ...
# 298  Wounded Lannister soldier
# 299        Wun Weg Wun Dar Wun
# 300             Othell Yarwyck
# 301                    Ygritte
# 302                      Yoren
#
#                                                  Born  \
# 0    Aemon Targaryen 202 AC Red Keep , King's Landing
# 1                    Dornish Marches , the Stormlands
# 2                Lysa Tully Riverrun , the Riverlands
# 3           289 AC (age 16) Red Keep , King's Landing
# 4                                                 NaN
# ..                                                ...
# 298                                        Lannisport
# 299                                   Beyond the Wall
# 300                                   The Westerlands
# 301                                   Beyond the Wall
# 302                                               NaN
#
#                                           Died  \
# 0    302 AC (aged 100) Castle Black , the Gift
# 1                                          NaN
# 2         301 AC The Eyrie , the Vale of Arryn
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 298                                        NaN
# 299              303 AC Winterfell , the North
# 300                        303 AC Castle Black
# 301             301 AC Castle Black , the Wall
# 302     299 AC Near Harrenhal , the Riverlands
#
#                                             House(s)  \
# 0                              Targaryen (renounced)
# 1                                                NaN
# 2    Tully Arryn (by marriage) Baelish (by marriage)
# 3                                              Arryn
# 4                                                NaN
# ..                                               ...
# 298                                              NaN
# 299                                              NaN
# 300                                          Yarwyck
# 301                                              NaN
# 302                                              NaN
#
#                              Affiliation(s)  \
# 0    ['Order of Maesters', "Night's Watch"]
# 1           ['Brotherhood Without Banners']
# 2                               ['Unknown']
# 3                                 ['Royce']
# 4                       ['Varys', 'Qyburn']
# ..                                      ...
# 298                           ['Lannister']
# 299            ['Mance Rayder', 'Jon Snow']
# 300                       ["Night's Watch"]
# 301                        ['Mance Rayder']
# 302                       ["Night's Watch"]
#
#                                               Title(s)    Culture  \
# 0                            Prince (formerly) Maester   Valyrian
# 1                                                  NaN    Marcher
# 2                                                  NaN   Rivermen
# 3    Lord of the Eyrie Defender of the Vale Warden ...    Valemen
# 4                                                  NaN        NaN
# ..                                                 ...        ...
# 298                                                NaN  Westermen
# 299                                                NaN      Giant
# 300                                      First Builder  Westermen
# 301                                                NaN  Free Folk
# 302                                                NaN  Westerosi
#
#                      Father            Mother  \
# 0    { Maekar I Targaryen }  { Dyanna Dayne }
# 1                       NaN               NaN
# 2          { Hoster Tully }  { Minisa Whent }
# 3             { Jon Arryn }    { Lysa Tully }
# 4                       NaN               NaN
# ..                      ...               ...
# 298               Fisherman               NaN
# 299                     NaN               NaN
# 300                     NaN               NaN
# 301                     NaN               NaN
# 302                     NaN               NaN
#
#                                             Sibling(s)  ...  \
# 0    { Daeron Targaryen } { Aerion Targaryen } { Ae...  ...
# 1                                                  NaN  ...
# 2                                                  NaN  ...
# 3                                                  NaN  ...
# 4                                                  NaN  ...
# ..                                                 ...  ...
# 298                                                NaN  ...
# 299                                                NaN  ...
# 300                                                NaN  ...
# 301                                                NaN  ...
# 302                                          {Brother}  ...
#
#                Religion        Issue Also known as Personal arms Species  \
# 0                   NaN          NaN           NaN           NaN     NaN
# 1         Lord of Light          NaN           NaN           NaN     NaN
# 2    Faith of the Seven  Robin Arryn           NaN           NaN     NaN
# 3                   NaN          NaN    Sweetrobin           NaN     NaN
# 4                   NaN          NaN           NaN           NaN     NaN
# ..                  ...          ...           ...           ...     ...
# 298  Faith of the Seven          NaN           NaN           NaN     NaN
# 299            Old Gods          NaN       Wun Wun           NaN     NaN
# 300  Faith of the Seven          NaN           NaN           NaN     NaN
# 301            Old Gods          NaN           NaN           NaN     NaN
# 302                 NaN          NaN           NaN           NaN     NaN
#
#     Affiliation  Lover(s) Family Dead           mapped
# 0           NaN       NaN    NaN    1            aemon
# 1           NaN       NaN    NaN    0            anguy
# 2           NaN       NaN    NaN    1       lysa arryn
# 3           NaN       NaN    NaN    0      robin arryn
# 4           NaN       NaN    NaN    0           arthur
# ..          ...       ...    ...  ...              ...
# 298         NaN       NaN    NaN    0  wounded soldier
# 299         NaN       NaN    NaN    1          wun wun
# 300         NaN       NaN    NaN    1   othell yarwick
# 301         NaN  Jon Snow    NaN    1          ygritte
# 302         NaN       NaN    NaN    1            yoren
#
# [303 rows x 28 columns]
