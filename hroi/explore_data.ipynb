# %%
import pandas as pd
import numpy as np

# %%
affiliations = pd.read_csv("../data/Affiliation_mortality.csv")
characters = pd.read_csv("../data/game_of_thrones_characters_cleaned.csv")

# %%
dialogues = pd.read_csv("../data/got_dialouge.csv")

# %%
affiliations
# Out:
#     Affiliation(s)  Alive  Dead  Total
# 0          Unknown     75    83    158
# 1    Night's Watch     31    40     71
# 2            Stark     36    39     75
# 3        Baratheon     17    30     47
# 4        Targaryen     15    26     41
# ..             ...    ...   ...    ...
# 75          Qyburn      2     0      2
# 76           Royce      3     0      3
# 77  Salladhor Saan      1     0      1
# 78     Sansa Stark      1     0      1
# 79      Tobho Mott      1     0      1
#
# [80 rows x 4 columns]

# %%
characters
# Out:
#                            Name  \
# 0                         Aemon
# 1                         Aggar
# 2    Aggo (The North Remembers)
# 3          Aggo (The Red Woman)
# 4                        Alanna
# ..                          ...
# 589                     Ygritte
# 590                       Yoren
# 591            Yunkai%27i whore
# 592                       Zalla
# 593                     Zanrush
#
#                                                  Born  \
# 0    Aemon Targaryen 202 AC Red Keep , King's Landing
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 589                                   Beyond the Wall
# 590                                               NaN
# 591                                               NaN
# 592                                 298 AC in Meereen
# 593                                               NaN
#
#                                                   Died               House(s)  \
# 0            302 AC (aged 100) Castle Black , the Gift  Targaryen (renounced)
# 1                        299 AC Winterfell , the North                    NaN
# 2                                                  NaN                    NaN
# 3                   303 AC Vaes Dothrak , Dothraki Sea                    NaN
# 4               305 AC King's Landing , the Crownlands                    NaN
# ..                                                 ...                    ...
# 589                     301 AC Castle Black , the Wall                    NaN
# 590             299 AC Near Harrenhal , the Riverlands                    NaN
# 591                                                NaN                    NaN
# 592  301 AC (aged 3) in Meereen Burned alive by Drogon                    NaN
# 593                                                NaN                    NaN
#
#                              Affiliation(s)                   Title(s)  \
# 0    ['Order of Maesters', "Night's Watch"]  Prince (formerly) Maester
# 1                               ['Greyjoy']                        NaN
# 2                    ['Drogo', 'Targaryen']                 Bloodrider
# 3                                  ['Moro']                        NaN
# 4                               ['Unknown']                        NaN
# ..                                      ...                        ...
# 589                        ['Mance Rayder']                        NaN
# 590                       ["Night's Watch"]                        NaN
# 591                        ['Wise Masters']                        NaN
# 592                             ['Unknown']                        NaN
# 593              ['Red Temple of Volantis']                        NaN
#
#                      Culture                  Father            Mother  \
# 0                   Valyrian  { Maekar I Targaryen }  { Dyanna Dayne }
# 1                   Ironborn                     NaN               NaN
# 2                   Dothraki                     NaN               NaN
# 3                   Dothraki                     NaN               NaN
# 4                        NaN                     NaN               NaN
# ..                       ...                     ...               ...
# 589                Free Folk                     NaN               NaN
# 590                Westerosi                     NaN               NaN
# 591                      NaN                     NaN               NaN
# 592  Ghiscari ( Meereenese )                Goatherd               NaN
# 593                Volantene                     NaN               NaN
#
#                                             Sibling(s)  ... Spouse(s)  \
# 0    { Daeron Targaryen } { Aerion Targaryen } { Ae...  ...       NaN
# 1                                                  NaN  ...       NaN
# 2                                                  NaN  ...       NaN
# 3                                                  NaN  ...       NaN
# 4                                                  NaN  ...   Husband
# ..                                                 ...  ...       ...
# 589                                                NaN  ...       NaN
# 590                                          {Brother}  ...       NaN
# 591                                                NaN  ...       NaN
# 592                                                NaN  ...       NaN
# 593                                                NaN  ...       NaN
#
#           Religion Issue Also known as Personal arms Species Affiliation  \
# 0              NaN   NaN           NaN           NaN     NaN         NaN
# 1              NaN   NaN           NaN           NaN     NaN         NaN
# 2              NaN   NaN           NaN           NaN     NaN         NaN
# 3              NaN   NaN           NaN           NaN     NaN         NaN
# 4              NaN   NaN           NaN           NaN     NaN         NaN
# ..             ...   ...           ...           ...     ...         ...
# 589       Old Gods   NaN           NaN           NaN     NaN         NaN
# 590            NaN   NaN           NaN           NaN     NaN         NaN
# 591            NaN   NaN           NaN           NaN     NaN         NaN
# 592            NaN   NaN           NaN           NaN     NaN         NaN
# 593  Lord of Light   NaN           NaN           NaN     NaN         NaN
#
#      Lover(s) Family Dead
# 0         NaN    NaN    1
# 1         NaN    NaN    1
# 2         NaN    NaN    0
# 3         NaN    NaN    1
# 4         NaN    NaN    1
# ..        ...    ...  ...
# 589  Jon Snow    NaN    1
# 590       NaN    NaN    1
# 591       NaN    NaN    0
# 592       NaN    NaN    1
# 593       NaN    NaN    0
#
# [594 rows x 27 columns]

# %%
affiliations.columns
# Out:
# Index(['Affiliation(s)', 'Alive', 'Dead', 'Total'], dtype='object')

# %%
dialogues.columns
# Out:
# Index(['Text', 'Speaker', 'Episode', 'Season', 'Show'], dtype='object')
